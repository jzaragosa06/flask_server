# %%
import sys
import os

# Add the directory containing the utility module to the system path
sys.path.append(os.path.abspath('/workspaces/flask_server'))

import pandas as pd
import numpy as np
from utility.lags import sig_lag
from models.stacking import *
from forecast.forecast_uni import *


df = pd.read_csv('/workspaces/flask_server/test/data/candy_production.csv', index_col=0, parse_dates=True)
df
# Out:
#                   IPG3113N
# observation_date
# 1972-01-01         85.6945
# 1972-02-01         71.8200
# 1972-03-01         66.0229
# 1972-04-01         64.5645
# 1972-05-01         65.0100
# ...                    ...
# 2017-04-01        107.4288
# 2017-05-01        101.9209
# 2017-06-01        104.2022
# 2017-07-01        102.5861
# 2017-08-01        114.0613
#
# [548 rows x 1 columns]

# %%
#identify the lag
lag = sig_lag(df, 30, ts_type = "univariate")
print(lag)
# Out:
# 29

# %%
pred = forecast_uni(df_arg=df, lag_value = int(lag), steps_value=12, freq = 'M', forecast_method="with_refit")
# Out:
#    IPG3113N
# 0   85.6945
# 1   71.8200
# 2   66.0229
# 3   64.5645
# 4   65.0100
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1068: UserWarning: Series has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/skforecast/utils/utils.py:1130: UserWarning: `last_window` has no DatetimeIndex nor RangeIndex index. Index is overwritten with a RangeIndex.
#   warnings.warn(
# /workspaces/flask_server/forecast/forecast_uni.py:89: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   #the occurence of gap uses DateTimeIndex

# %%
pred
# Out:
#                 target
# 2017-09-30  115.812106
# 2017-10-31  124.327739
# 2017-11-30  121.711817
# 2017-12-31  119.851715
# 2018-01-31  111.446319
# 2018-02-28  112.125630
# 2018-03-31  107.610264
# 2018-04-30  107.890912
# 2018-05-31  103.556393
# 2018-06-30  104.148041
# 2018-07-31  104.120568
# 2018-08-31  110.536409
